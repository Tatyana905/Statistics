# %% [markdown]
# <a href="https://colab.research.google.com/github/Allajka/statistics/blob/main/seminar_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание 1
# Когда используется критерий Стьюдента, а когда Z –критерий?
#
# Оба параметрических критерия используем, когда присутствует нормальность(следуют нормальному распределению), **но**:
#
# **Z критерий** - используем когда известна 𝞼(стандартное отклонение) генеральной совокупности
#
# **t - критерий (критерий Стьюдента)** - если 𝞼(стандартное отклонение) генеральной совокупности неизвестна, равенство дисперсий

# %% [markdown]
# # Задание 2
#
# Проведите тест гипотезы.
#
# *Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.*
#
# Используя односторонний критерий с **α=0,05**, проверить эту гипотезу, если в выборке из **n=100** шариков **средний диаметр оказался равным 17.5 мм**, а **дисперсия известна и равна 4 кв. мм.**

# %% [markdown]
# Дано:
#   $$n = 100,  \overline{x} = 17,5 мм, μ (среднее арифметическое) =  17  мм$$
#   $$D = 4 кв. мм., α (уровень стат. значимости) = 0,05$$
#
# Так как нам дана информация о дисперсии генеральной совокупности, для тестирования гипотезы используем Z –критерий:
#
#   $$Z_h = \frac{\overline{x} - μ} {\frac{\sqrt{𝞼}}{\sqrt{{n}}}}$$
#   $$Z_h = \frac{17,5 - 17} {\frac{\sqrt{4}}{\sqrt{100} }}$$

# %%
Z = (17.5 - 17)/ (4**0.5/100**0.5)
print(f'Z расчетный равен {Z}.')
# Out:
# Z расчетный равен 2.5.

# %% [markdown]
# ![Безымянный.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Z_расчетный = 2.5
#
# Z_табличный α = 0.05 = -1,645
#
# Z_табличный α = 0.95 = 1,645
#
# $$Z_расчетный > Z_табличный$$
#
# **Ответ: Отвергаем гипотезу, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.**

# %% [markdown]
# # Задание 3
# Проведите тест гипотезы.
#
# *Продавец утверждает, что средний вес пачки печенья составляет 200 г.*
#
#
# Из партии извлечена выборка из 10 пачек.
#
# Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест).

# %% [markdown]
# **1. Сформулируем нулевую гипотезу:**
#
#   $$ H_0: μ_1 = μ_0 = 200 г. $$
#
#   $$ H_1: μ_1 \neq μ _0$$
#
# **2. Выбор уровня статистической значимости α(альфа):**
#
# α(альфа) = 0,01(1%) - по условию
#
# **3. Выбор статистического критерия t - критерий (критерий Стьюдента), т.к. 𝞼 генеральной совокупности неизвестна**

# %% [markdown]
# **4. Расчет наблюдаемого критерия по выборке**

# %%
import numpy as np

# %%
x =np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])

# %%
d1 = np.var(x, ddof=1)
d1
# Out:
# 19.833333333333332

# %%
m1 = np.mean(x)
m1
# Out:
# 198.5

# %% [markdown]
# D(X) = 19.834, x(сред. арифм.) = 198.5, μ = 200
#
# Производим расчет t - критерий (критерий Стьюдента) по формуле:
#
# $$t = \frac{\overline{x} - μ} {\sqrt{\frac{D(X)}{n}}}$$

# %%
μ = 200
t = (m1 - μ) /np.sqrt(d1/len(x)) 
t
# Out:
# -1.0651074037450896

# %% [markdown]
# **5. Сравнение табличного и наблюдаемого значения**
#
# Ищем t_табличное.
#
# Так как по условию сказано провести двусторонний тест - ищем 1% в таблице для двусторонего критерия Стьюдента
#
# t(α = 0,01, степени свободы 9) = 3,25
#
# **6. Вывод**
#
# t_расчетное = -1,065
#
# t_табличное = 3,25
#
# При двустороннем тесте используем абсолютные значения
#
# t_табличное > t_расчетное
#
# **Ответ: принимаем нулевую теорию, нет статистически важных различий.**

# %% [markdown]
# # Задача 4
# Есть ли статистически значимые различия в росте дочерей и матерей?
#
# Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169
#
# Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160

# %% [markdown]
# **1. Сформулируем нулевую гипотезу:**
#
# Нет статистически важных различий:
#   $$ H_0: μ_1 = μ_0$$
#
# Есть различия:
#   $$ H_1: μ_1 \neq μ _0$$
#
# **2. Выбор уровня статистической значимости α(альфа):**
#
# α(альфа) = 0,05(5%)
#
# **3. Выбор статистического критерия t - критерий (критерий Стьюдента), т.к. 𝞼 генеральной совокупности неизвестна**

# %% [markdown]
# **4. Расчет наблюдаемого критерия по выборке** выполним с помощью функции в Python используя двухвыборочный тест с зависимыми выборками(подразумевая что рост зависит от ДНК родителей).

# %%
import scipy.stats as stats

# %%
mothers = np.array([172, 177, 158, 170, 178,175, 164, 160, 169]) 
daughters = np.array([173, 175, 162, 174, 175, 168, 155, 170, 160])

# %%
stats.ttest_rel(mothers,daughters)
# Out:
# Ttest_relResult(statistic=0.559522990335608, pvalue=0.5911212354055175)

# %% [markdown]
# Полученные значения мы сравниваем либо:
#
# * pvalue = 0,559 > α(альфа) = 0,05
# * statistic = 0,591 < табличное значение = 2,306
#
# **Ответ: принимаем нулевую теорию, нет статистически важных различий**
